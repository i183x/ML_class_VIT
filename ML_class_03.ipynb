# %%
#trainer : Saumya

# %%
#Tuples (Ordered, indexing, slicing, immutable, allows duplicates)

# %%
tup = (1, 'i183x', 183)

# %%
tup
# Out:
# (1, 'i183x', 183)

# %%
tup[1]
# Out:
# 'i183x'

# %%
tup[1:3]
# Out:
# ('i183x', 183)

# %%
tup = (1, 'i183x', 183, 1, 12)

# %%
tup
# Out:
# (1, 'i183x', 183, 1, 12)

# %%
#Set (no duplicates, unordered, no indexing & slicing, immutable)

# %%
st = {1,1,'Atul', 'Manu', 183.3, 'i183x', 'Krishna', 'Krishna'}

# %%
st
# Out:
# {1, 183.3, 'Atul', 'Krishna', 'Manu', 'i183x'}

# %%
#dictonary {key:value}
dict_1 = {1:['Manu','goru'],
          2: 'Krishna',
          3: 'Jaskaran',
          4: 'haha'}

dict_1
# Out:
# {1: ['Manu', 'goru'], 2: 'Krishna', 3: 'Jaskaran', 4: 'haha'}

# %%
trial_dict = {1:['Manu','goru'],
          2: 'Krishna',
          3: 'Jaskaran',
          4: 'haha',
          'a': 1,
          'b': 4}
trial_dict
# Out:
# {1: ['Manu', 'goru'], 2: 'Krishna', 3: 'Jaskaran', 4: 'haha', 'a': 1, 'b': 4}

# %%
trial_dict.keys()
# Out:
# dict_keys([1, 2, 3, 4, 'a', 'b'])

# %%
trial_dict.values()
# Out:
# dict_values([['Manu', 'goru'], 'Krishna', 'Jaskaran', 'haha', 1, 4])

# %%
trial_dict.items()
# Out:
# dict_items([(1, ['Manu', 'goru']), (2, 'Krishna'), (3, 'Jaskaran'), (4, 'haha'), ('a', 1), ('b', 4)])

# %%
trial_dict[3]
# Out:
# 'Jaskaran'

# %%
#changing values
trial_dict['a'] = 'pyaar'
trial_dict['b'] = 'dost'
trial_dict
# Out:
# {1: ['Manu', 'goru'],
#  2: 'Krishna',
#  3: 'Jaskaran',
#  4: 'haha',
#  'a': 'pyaar',
#  'b': 'dost'}

# %%
ml_class = {

            'name' : ['Krishn', 'Ishan', 'Ketan', 'Harsh','Kuch aur chutiye' ],
            'org' : ['SmartInterz', 'loda lesun'],
            'inst' : 'VIT'
            }

ml_class
# Out:
# {'name': ['Krishn', 'Ishan', 'Ketan', 'Harsh', 'Kuch aur chutiye'],
#  'org': ['SmartInterz', 'loda lesun'],
#  'inst': 'VIT'}

# %%
ml_class['name']
# Out:
# ['Krishn', 'Ishan', 'Ketan', 'Harsh', 'Kuch aur chutiye']

# %%
ml_class['name'][1]
# Out:
# 'Ishan'

# %%
ml_class['name'][::2]
# Out:
# ['Krishn', 'Ketan', 'Kuch aur chutiye']

# %%
#conditions

a = 10
if a>9:
  print(a)

a = int(input('Enter value of a: '))
a
# Out:
# 10
# Enter value of a: 22
# 22

# %%
for i in [1, 2, 3, 4][::-1]:
    print (i)
# Out:
# 4
# 3
# 2
# 1
